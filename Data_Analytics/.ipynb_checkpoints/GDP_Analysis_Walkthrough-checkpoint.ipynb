# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("gdp.csv")

# %%
data
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
data.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
data["Country Name"].count()
# Out:
# np.int64(11507)

# %%
data.shape
# Out:
# (11507, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11507 entries, 0 to 11506
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  11507 non-null  object
#  1   Country Code  11507 non-null  object
#  2   Year          11507 non-null  int64
#  3   Value         11507 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 359.7+ KB

# %%
data.isna().sum()
# Out:
# Country Name    0
# Country Code    0
# Year            0
# Value           0
# dtype: int64

# %% [markdown]
# **1) How many unique Countries Data we're having in the dataset?**

# %%
data["Country Name"].nunique()
# Out:
# 256

# %% [markdown]
# **2) How many years of Data we're having for India**

# %%
 data[data["Country Name"] == "India"]["Year"].nunique()
# Out:
# 57

# %% [markdown]
# **3) Whats the world GDP in 1969?**

# %%
data.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
data[data["Year"]==1969].sum()
# Out:
# Country Name    Arab WorldCaribbean small statesEarly-demograp...
# Country Code    ARBCSSEAREASEAPTEAEMUECSEUUHPCHICIBDIBTIDBIDAL...
# Year                                                       299288
# Value                                       19577201579296.539062
# dtype: object

# %%
#GDP: 19577201579296.539062

# %% [markdown]
# *4)Whats the % of GDP growth of India in Year 1994 (*as compare to 1993)?**

# %%
a = data.loc[(data["Year"] == 1994) & (data["Country Name"] == "India")]
value1 = a["Value"].values[0]  # Extract the value as a scalar
print(value1)
# Out:
# 322909902308.131

# %%
a = data.loc[(data["Year"] == 1993) & (data["Country Name"] == "India")]
value2 = a["Value"].values[0]  # Extract the value as a scalar
print(value2)
# Out:
# 275570363432.31

# %%
percentage_gdp_growth=(value1-value2)*100/value1
print(percentage_gdp_growth,"%")
# Out:
# 14.660293331806246 %

# %%
#Tasks
#1) Find GDP Growth of India from 1960 - 2016
#2) Create a new columns named as GDP which shows the GDP growth of each country for that year
#3) Create a graph of GDP Growth of India from 1960 - 2016

# %%
data.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df=data[data["Country Name"]=="India"]
df
# Out:
#      Country Name Country Code  Year         Value
# 6074        India          IND  1960  3.653593e+10
# 6075        India          IND  1961  3.870910e+10
# 6076        India          IND  1962  4.159907e+10
# 6077        India          IND  1963  4.777600e+10
# 6078        India          IND  1964  5.572687e+10
# 6079        India          IND  1965  5.876042e+10
# 6080        India          IND  1966  4.525364e+10
# 6081        India          IND  1967  4.946617e+10
# 6082        India          IND  1968  5.237732e+10
# 6083        India          IND  1969  5.766833e+10
# 6084        India          IND  1970  6.158980e+10
# 6085        India          IND  1971  6.645256e+10
# 6086        India          IND  1972  7.050991e+10
# 6087        India          IND  1973  8.437454e+10
# 6088        India          IND  1974  9.819828e+10
# 6089        India          IND  1975  9.715922e+10
# 6090        India          IND  1976  1.013470e+11
# ...

# %%
sns.lineplot(x="Value",y="Year",data=df)
# Out:
# <Axes: xlabel='Value', ylabel='Year'>

# %%
data.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
round((2.843420e+10-2.576068e+10)*100/2.843420e+10,2)
# Out:
# 9.4

# %%
gdp_inc=[0]
for i in range(1, len(data)):
    curr_year=data.iloc[i, 3]
    prev_year=data.iloc[i-1,3]
    gdp_inc.append(round((((curr_year-prev_year) *100) /curr_year),2))

# %%
d=data.assign(GDP=gdp_inc)
d
# Out:
#       Country Name Country Code  Year         Value    GDP
# 0       Arab World          ARB  1968  2.576068e+10   0.00
# 1       Arab World          ARB  1969  2.843420e+10   9.40
# 2       Arab World          ARB  1970  3.138550e+10   9.40
# 3       Arab World          ARB  1971  3.642691e+10  13.84
# 4       Arab World          ARB  1972  4.331606e+10  15.90
# ...            ...          ...   ...           ...    ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10  15.05
# 11503     Zimbabwe          ZWE  2013  1.545177e+10   7.83
# 11504     Zimbabwe          ZWE  2014  1.589105e+10   2.76
# 11505     Zimbabwe          ZWE  2015  1.630467e+10   2.54
# 11506     Zimbabwe          ZWE  2016  1.661996e+10   1.90
#
# [11507 rows x 5 columns]

# %%
d[d["Country Name"]=="India"]["GDP"]
# Out:
# 6074    45.13
# 6075     5.61
# 6076     6.95
# 6077    12.93
# 6078    14.27
# 6079     5.16
# 6080   -29.85
# 6081     8.52
# 6082     5.56
# 6083     9.17
# 6084     6.37
# 6085     7.32
# 6086     5.75
# 6087    16.43
# 6088    14.08
# 6089    -1.07
# 6090     4.13
# 6091    15.45
# 6092    11.52
# 6093    10.26
# 6094    17.89
# 6095     3.70
# 6096     3.60
# 6097     8.04
# 6098    -2.88
# 6099     8.75
# 6100     6.62
# 6101    10.77
# 6102     5.92
# 6103    -0.18
# 6104     7.77
# 6105   -18.83
# 6106     6.28
# 6107    -3.19
# 6108    14.66
# 6109     9.16
# 6110     8.30
# 6111     5.52
# 6112     1.30
# 6113     8.17
# 6114     2.04
# 6115     3.51
# 6116     5.73
# 6117    15.26
# 6118    14.31
# 6119    13.50
# 6120    12.11
# 6121    23.38
# 6122    -1.19
# 6123    10.35
# 6124    20.08
# 6125     9.13
# 6126     0.25
# 6127     1.57
# 6128     8.78
# 6129     2.61
# 6130     7.68
# Name: GDP, dtype: float64
