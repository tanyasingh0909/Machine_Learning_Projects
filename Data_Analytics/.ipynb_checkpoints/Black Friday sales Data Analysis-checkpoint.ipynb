# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("BlackFriday.csv")
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
data.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data.isna()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 537572    False       False   False  False       False          False
# 537573    False       False   False  False       False          False
# 537574    False       False   False  False       False          False
# 537575    False       False   False  False       False          False
# 537576    False       False   False  False       False          False
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# ...

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
#deleting coloumns having null values

del data["Product_Category_2"]
del data["Product_Category_3"]
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data["User_ID"].nunique()
# Out:
# 5891

# %%
data["Product_ID"].nunique()
# Out:
# 3623

# %%
data["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
data["Occupation"].nunique()
# Out:
# 21

# %%
data["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
data["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
data["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
data["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9])

# %%
data["Purchase"].sum()/len(data["Purchase"])
# Out:
# np.float64(9333.859852635065)

# %%
for column in data.columns:
    print(column,":",data[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df=pd.DataFrame({"ratio":[len(data[data["Gender"]=="M"]),len(data[data["Gender"]=="F"])]},index=["Male","Female"])
df
# Out:
#          ratio
# Male    405380
# Female  132197

# %%
df["ratio"].plot(kind="pie",figsize=(3,3),autopct="% .2f")
# Out:
# <Axes: ylabel='ratio'>

# %%
data.groupby("Gender").size().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
lst=[]
for i in data["Age"].unique():
  lst.append([i,data[data["Age"]==i]["Product_ID"].nunique()])
lst
# Out:
# [['0-17', 2300],
#  ['55+', 2573],
#  ['26-35', 3419],
#  ['46-50', 3099],
#  ['51-55', 2877],
#  ['36-45', 3318],
#  ['18-25', 3213]]

# %%
df=pd.DataFrame(lst,columns=["Age","Purchase"])
df
# Out:
#      Age  Purchase
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
df.plot.bar(x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
data.groupby('Age').sum()["Purchase"].plot(kind="bar",title="Purchase made by age")
# Out:
# <Axes: title={'center': 'Purchase made by age'}, xlabel='Age'>

# %%
data.groupby('Marital_Status').size().plot(kind="pie",title="Marital Status",autopct="% .2f")
# Out:
# <Axes: title={'center': 'Marital Status'}>

# %%
data.groupby('Gender').size().plot(kind="pie",title="Gender",autopct="% .2f")
# Out:
# <Axes: title={'center': 'Gender'}>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(data=data,x="Age",hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
data.groupby("City_Category").size().plot(kind="bar")
# Out:
# <Axes: xlabel='City_Category'>

# %%
sns.countplot(data=data,x="City_Category",hue="Age")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data=data,x="Age",hue="Marital_Status")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data=data,x="City_Category",hue="Gender")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
data.groupby("City_Category").sum()["Purchase"].plot(kind="pie",autopct="% .2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(data=data,x="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=data,x="Stay_In_Current_City_Years",hue="Age")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=data,x="Stay_In_Current_City_Years",hue="Marital_Status")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=data,x="Stay_In_Current_City_Years",hue="City_Category")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=data,x="Stay_In_Current_City_Years",hue="Gender")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data=data,x="City_Category",hue="Age")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
data.groupby("Stay_In_Current_City_Years").size().plot(kind="pie",autopct="% .2f")
# Out:
# <Axes: >

# %%
data.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
data.groupby("Occupation").size().plot(kind="pie",autopct="% .1f")
# Out:
# <Axes: >

# %%
data.groupby("Occupation").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
data.groupby("Occupation").sum()["Purchase"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x="Occupation", hue="Marital_Status",data=data)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x="Occupation", hue="Gender",data=data)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
data.groupby("Occupation").nunique()["Product_ID"].plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
data.groupby("Occupation").nunique()["Product_ID"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
data.groupby("Product_Category_1").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
data.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
sns.countplot(x="Product_Category_1",hue="Gender",data=data)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x="Product_Category_1",hue="Marital_Status",data=data)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
data["Gender"]
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 537572    M
# 537573    M
# 537574    M
# 537575    M
# 537576    M
# Name: Gender, Length: 537577, dtype: object

# %%
data["Gender_MaritalStatus"] = data["Gender"].astype(str) + " " + data["Marital_Status"].astype(str)
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Gender_MaritalStatus
# 0                  F 0
# 1                  F 0
# 2                  F 0
# 3                  F 0
# 4                  M 0

# %%
sns.countplot(x="Gender_MaritalStatus",data=data)
# Out:
# <Axes: xlabel='Gender_MaritalStatus', ylabel='count'>

# %%
sns.countplot(x="Age",hue="Gender_MaritalStatus",data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Gender",hue="Gender_MaritalStatus",data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Marital_Status",hue="Gender_MaritalStatus",data=data)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x="Occupation",hue="Gender_MaritalStatus",data=data)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x="City_Category",hue="Gender_MaritalStatus",data=data)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years",hue="Gender_MaritalStatus",data=data)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>
